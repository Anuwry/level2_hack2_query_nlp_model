# %%
import pandas as pd

file_path = r"D:\sup_ai\query_mock\cctv_vehicle_log_routed.csv"
df = pd.read_csv(file_path)

filtered_df = df[
    (df['CCTV_ID'].astype(str).str.lower() == 'cctv02') &
    (df['Event'].astype(str).str.lower() == 'entry')
]

print(filtered_df)
# Out:
#             Date CCTV_ID Timestamp       Brand   Color        Type  Event
# 124   10-05-2026  CCTV02  07:39:29  Motorcycle     Red  Motorcycle  entry
# 152   10-05-2026  CCTV02  07:57:03  Motorcycle   Black  Motorcycle  entry
# 155   10-05-2026  CCTV02  07:58:33       Honda    Gray         Car  entry
# 413   10-05-2026  CCTV02  13:55:01  Motorcycle   Black  Motorcycle  entry
# 421   10-05-2026  CCTV02  14:14:27        Ford  Silver         Car  entry
# ...          ...     ...       ...         ...     ...         ...    ...
# 9597  14-05-2026  CCTV02  21:29:22      Toyota  Bronze         Car  entry
# 9602  14-05-2026  CCTV02  21:30:19      Toyota     Red         Car  entry
# 9682  14-05-2026  CCTV02  22:00:16       Haval   Black         Car  entry
# 9759  14-05-2026  CCTV02  22:21:48  Motorcycle    Gray  Motorcycle  entry
# 9835  14-05-2026  CCTV02  22:51:06      Toyota  Silver         Car  entry
#
# [222 rows x 7 columns]

# %%
import pandas as pd

df = pd.read_csv(r"D:\sup_ai\query_mock\cctv_vehicle_log_routed.csv")
honda_red = df[(df['Type'].str.lower() == 'bus')]

total_logs = len(honda_red)
actual_cars = len(honda_red[honda_red['Event'].str.lower() == 'entry'])

print(f"พบประวัติรถ Honda สีแดงในระบบทั้งหมด: {total_logs} ครั้ง")
print(f"คิดเป็นจำนวนรถจริง (นับจากตั๋วขาเข้า): {actual_cars} คัน")
# Out:
# พบประวัติรถ Honda สีแดงในระบบทั้งหมด: 628 ครั้ง
# คิดเป็นจำนวนรถจริง (นับจากตั๋วขาเข้า): 203 คัน

# %%
import csv
import shutil
from pathlib import Path

CSV_PATH = Path("cctv_vehicle_log_routed.csv")
BACKUP_PATH = Path("cctv_vehicle_log_routed.backup.csv")

shutil.copy2(CSV_PATH, BACKUP_PATH)

with CSV_PATH.open("r", encoding="utf-8-sig", newline="") as f:
    reader = csv.DictReader(f)
    fieldnames = reader.fieldnames
    rows = []

    for row in reader:
        vehicle_type = (row.get("Type") or "").strip()

        if vehicle_type == "Motorcycle":
            row["Brand"] = "Motorcycle"
        elif vehicle_type == "Truck":
            row["Brand"] = "Hino"

        rows.append(row)

with CSV_PATH.open("w", encoding="utf-8", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(rows)

print(f"Updated: {CSV_PATH}")
print(f"Backup: {BACKUP_PATH}")
# Out:
# Updated: cctv_vehicle_log_routed.csv
# Backup: cctv_vehicle_log_routed.backup.csv
